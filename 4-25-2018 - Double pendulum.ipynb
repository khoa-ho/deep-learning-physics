# %% [markdown]
# # Approximating a double pendulum

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, LSTM, CuDNNLSTM, Bidirectional

import random
from random import seed, random
from sklearn.utils import shuffle

# %matplotlib inline
# Out:
# /home/bipe26194/miniconda3/envs/tensorflow/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from matplotlib.patches import Circle

# Pendulum rod lengths (m), bob masses (kg).
L1, L2 = 1, 1
m1, m2 = 1, 1
# The gravitational acceleration (m.s-2).
g = 9.81

def deriv(y, t, L1, L2, m1, m2):
    """Return the first derivatives of y = theta1, z1, theta2, z2."""
    theta1, z1, theta2, z2 = y

    c, s = np.cos(theta1-theta2), np.sin(theta1-theta2)

    theta1dot = z1
    z1dot = (m2*g*np.sin(theta2) - m2*s*(L1*z1**2*c + L2*z2**2) -
             (m1+m2)*g*np.sin(theta1)) / L1 / (m1 + m2*s**2)
    theta2dot = z2
    z2dot = ((m1+m2)*(L1*z1**2*s - g*np.sin(theta2) + g*np.sin(theta1)*c) + 
             m2*L2*z2**2*s*c) / L2 / (m1 + m2*s**2)
    return theta1dot, z1dot, theta2dot, z2dot

# Maximum time, time point spacings and the time grid (all in s).
tmax, dt = 100, 0.01
t = np.arange(0, tmax+dt, dt)
# Initial conditions.
y0 = [np.pi/2, 0, np.pi/2, 0]

# Do the numerical integration of the equations of motion
y = odeint(deriv, y0, t, args=(L1, L2, m1, m2))
# Unpack z and theta as a function of time
theta1, theta2 = y[:,0], y[:,2]

# Convert to Cartesian coordinates of the two bob positions.
x1 = L1 * np.sin(theta1)
y1 = -L1 * np.cos(theta1)
x2 = x1 + L2 * np.sin(theta2)
y2 = y1 - L2 * np.cos(theta2)

plt.plot(theta1)
plt.plot(theta2)
theta_pair = [[x[0], x[1]] for x in zip(theta1, theta2)]
data = theta_pair
print(np.shape(data))
# Out:
# (10001, 2)

# %%
def _load_data(data, n_prev = 100):
    """
    data should be pd.DataFrame()
    """
    docX, docY = [], []
    for i in range(len(data)-n_prev):
        docX.append(data[i:i+n_prev])
        docY.append(data[i+n_prev])
    alsX = np.array(docX)
    alsY = np.array(docY)

    return alsX, alsY

def train_test_split(df, test_size=0.2):  
    """
    This just splits data to training and testing parts
    """
    ntrn = int(round(len(df) * (1 - test_size)))

    X_train, y_train = _load_data(df[0:ntrn])
    X_test, y_test = _load_data(df[ntrn:])

    return (X_train, y_train), (X_test, y_test)

# retrieve data
(X_train, y_train), (X_test, y_test) = train_test_split(data, 0.6)

# %%
X_train.shape
# Out:
# (3900, 100, 2)

# %%
# define model structure
model = Sequential()
model.add(Bidirectional(LSTM(units=100, return_sequences=False), input_shape=(None, 2)))
# model.add(Bidirectional(LSTM(units=100, return_sequences=False)))
# model.add(Dense(units=10, activation="selu"))
model.add(Dense(units=2, activation="linear"))
model.compile(loss="mean_squared_error", optimizer="adam")

# %%
# and now train the model
# batch_size should be appropriate to your memory size
# number of epochs should be higher for real world problems
model.fit(X_train, y_train, batch_size=64, epochs=20, validation_split=0.1)
# Out:
# Train on 3510 samples, validate on 390 samples
# Epoch 1/20
# 3510/3510 [==============================] - 12s 3ms/step - loss: 0.1884 - val_loss: 0.0211
# Epoch 2/20
# 3510/3510 [==============================] - 6s 2ms/step - loss: 0.0068 - val_loss: 0.0049
# Epoch 3/20
# 3510/3510 [==============================] - 6s 2ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 4/20
# 3510/3510 [==============================] - 6s 2ms/step - loss: 0.0011 - val_loss: 0.0026
# Epoch 5/20
# 3510/3510 [==============================] - 6s 2ms/step - loss: 8.6586e-04 - val_loss: 0.0021
# Epoch 6/20
# 3510/3510 [==============================] - 6s 2ms/step - loss: 7.0701e-04 - val_loss: 0.0028
# Epoch 7/20
# 3510/3510 [==============================] - 6s 2ms/step - loss: 6.0974e-04 - val_loss: 0.0018
# Epoch 8/20
# 3510/3510 [==============================] - 6s 2ms/step - loss: 5.0864e-04 - val_loss: 0.0019
# Epoch 9/20
# 3510/3510 [==============================] - 6s 2ms/step - loss: 4.4839e-04 - val_loss: 0.0018
# Epoch 10/20
# 3510/3510 [==============================] - 6s 2ms/step - loss: 3.9192e-04 - val_loss: 0.0013
# Epoch 11/20
# 3510/3510 [==============================] - 6s 2ms/step - loss: 3.4016e-04 - val_loss: 0.0013
# Epoch 12/20
# 3510/3510 [==============================] - 6s 2ms/step - loss: 3.3966e-04 - val_loss: 0.0017
# Epoch 13/20
# 3510/3510 [==============================] - 6s 2ms/step - loss: 2.8206e-04 - val_loss: 0.0012
# Epoch 14/20
# 3510/3510 [==============================] - 6s 2ms/step - loss: 2.5148e-04 - val_loss: 0.0013
# Epoch 15/20
# 3510/3510 [==============================] - 6s 2ms/step - loss: 2.2437e-04 - val_loss: 0.0015
# Epoch 16/20
# 3510/3510 [==============================] - 6s 2ms/step - loss: 2.0652e-04 - val_loss: 0.0020
# Epoch 17/20
# 3510/3510 [==============================] - 6s 2ms/step - loss: 1.9858e-04 - val_loss: 0.0017
# Epoch 18/20
# 3510/3510 [==============================] - 6s 2ms/step - loss: 1.6636e-04 - val_loss: 0.0025
# Epoch 19/20
# 3510/3510 [==============================] - 6s 2ms/step - loss: 1.5726e-04 - val_loss: 0.0020
# Epoch 20/20
# 3510/3510 [==============================] - 6s 2ms/step - loss: 1.5848e-04 - val_loss: 0.0023

# %%
# evaluate model fit
score = model.evaluate(X_test, y_test)
print('Test score:', score)
# Out:
# 5901/5901 [==============================] - 3s 472us/step
# Test score: 0.002553359409274969

# %%
# visualize predictions
train_prediction = model.predict(X_train)
test_prediction = model.predict(X_test)

# %%
t_test = np.arange(0, len(y_test)*dt, dt)
plt.figure(figsize=(20,10))
plt.plot(t_test, y_test[:], label='test_data')
plt.plot(t_test, test_prediction[:], label='test_pred')
plt.title('Test Observation and Prediction')
plt.legend()

# %%
t_train = np.arange(0, len(y_train)*dt, dt)
plt.figure(figsize=(20,10))
plt.plot(t_train, y_train[0:], label='train_data')
plt.plot(t_train, train_prediction[0:], label='train_pred')
plt.title('Train Observation and Prediction')
plt.legend()
